# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,3,5, np.nan, 6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# date series
dates = pd.date_range("20231125", periods=6)
dates
# Out:
# DatetimeIndex(['2023-11-25', '2023-11-26', '2023-11-27', '2023-11-28',
#                '2023-11-29', '2023-11-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
#make a datafarme and assign random values as in below
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-11-25 -0.879978  0.475203  0.126493 -0.356146
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243

# %%
# Dictionary
dict = {"Taskeen":5.9, "azam":5.6}
dict
# Out:
# {'Taskeen': 5.9, 'azam': 5.6}

# %%
df_2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20241125"),
        "C": pd.Series(1, index=list(range(4)),dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df_2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2024-11-25  1.0  3   test  foo
# 1  1.0 2024-11-25  1.0  3  train  foo
# 2  1.0 2024-11-25  1.0  3   test  foo
# 3  1.0 2024-11-25  1.0  3  train  foo

# %%
df_2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[s](1), float32(1), float64(1), int32(1), object(1)
# memory usage: 288.0+ bytes

# %%
# Veiwing data
df.head
# Out:
# <bound method NDFrame.head of                    A         B         C         D
# 2023-11-25 -0.879978  0.475203  0.126493 -0.356146
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243>

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243

# %%
df.index
# Out:
# DatetimeIndex(['2023-11-25', '2023-11-26', '2023-11-27', '2023-11-28',
#                '2023-11-29', '2023-11-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
# To convert into numpy 
df.to_numpy()
# Out:
# array([[-0.87997785,  0.47520269,  0.12649347, -0.35614641],
#        [ 1.29485861, -1.20809705,  1.7999793 ,  1.59417587],
#        [-0.63117014,  0.71335836, -1.72234331, -0.83428162],
#        [-1.33502929, -3.12263696,  0.2242601 ,  0.65456594],
#        [-1.54643331, -0.69060134, -2.24632204, -2.26750461],
#        [-0.87542387,  0.51937093,  0.20111906,  0.07524273]])

# %%
# To convert into numpy 
df_2.to_numpy()
# Out:
# array([[1.0, Timestamp('2024-11-25 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2024-11-25 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2024-11-25 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2024-11-25 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.662196 -0.552234 -0.269469 -0.188991
# std    1.015726  1.473904  1.478067  1.321034
# min   -1.546433 -3.122637 -2.246322 -2.267505
# 25%   -1.221266 -1.078723 -1.260134 -0.714748
# 50%   -0.877701 -0.107699  0.163806 -0.140452
# 75%   -0.692234  0.508329  0.218475  0.509735
# max    1.294859  0.713358  1.799979  1.594176

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# A    6.0 -0.662196  1.015726 -1.546433 -1.221266 -0.877701 -0.692234  1.294859
# B    6.0 -0.552234  1.473904 -3.122637 -1.078723 -0.107699  0.508329  0.713358
# C    6.0 -0.269469  1.478067 -2.246322 -1.260134  0.163806  0.218475  1.799979
# D    6.0 -0.188991  1.321034 -2.267505 -0.714748 -0.140452  0.509735  1.594176

# %% [markdown]
# ### Sorting through index
# ### Ascending order left to right/ from small number to large number
# ### Descending order downword / from large number to small number
# ### A upward
# ### D downward

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2023-11-25 -0.356146  0.126493  0.475203 -0.879978
# 2023-11-26  1.594176  1.799979 -1.208097  1.294859
# 2023-11-27 -0.834282 -1.722343  0.713358 -0.631170
# 2023-11-28  0.654566  0.224260 -3.122637 -1.335029
# 2023-11-29 -2.267505 -2.246322 -0.690601 -1.546433
# 2023-11-30  0.075243  0.201119  0.519371 -0.875424

# %%
# Sorting the DataFrame by index in descending order
df.sort_index(ascending=False, inplace=True)
df
# Out:
#                    A         B         C         D
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176
# 2023-11-25 -0.879978  0.475203  0.126493 -0.356146

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-25 -0.879978  0.475203  0.126493 -0.356146
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282

# %%
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566
# 2023-11-25 -0.879978  0.475203  0.126493 -0.356146
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243
# 2023-11-27 -0.631170  0.713358 -1.722343 -0.834282
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176

# %%
df[["A", "B"]]
# Out:
#                    A         B
# 2023-11-30 -0.875424  0.519371
# 2023-11-29 -1.546433 -0.690601
# 2023-11-28 -1.335029 -3.122637
# 2023-11-27 -0.631170  0.713358
# 2023-11-26  1.294859 -1.208097
# 2023-11-25 -0.879978  0.475203

# %%
df.iloc[0:2,0:3] # iloc is used to loc the index
# Out:
#                    A         B         C
# 2023-11-30 -0.875424  0.519371  0.201119
# 2023-11-29 -1.546433 -0.690601 -2.246322

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2023-11-30 -0.875424  0.519371
# 2023-11-29 -1.546433 -0.690601
# 2023-11-28 -1.335029 -3.122637
# 2023-11-27 -0.631170  0.713358
# 2023-11-26  1.294859 -1.208097
# 2023-11-25 -0.879978  0.475203

# %%
# Selection by position
df.iloc[0:3]
# Out:
#                    A         B         C         D
# 2023-11-30 -0.875424  0.519371  0.201119  0.075243
# 2023-11-29 -1.546433 -0.690601 -2.246322 -2.267505
# 2023-11-28 -1.335029 -3.122637  0.224260  0.654566

# %%
# Selection by position index three and transpose it
df.iloc[3]
# Out:
# A   -0.631170
# B    0.713358
# C   -1.722343
# D   -0.834282
# Name: 2023-11-27 00:00:00, dtype: float64

# %% [markdown]
# ### Three points are very important in data wrangling
# - **Data Ingestion**: This is the process of getting data into your system. This can
# - iloc, loc, indexing

# %%
# EDA on the data of titanic/  kashti(Explainatory Data Analysis)
import seaborn as sns
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 209         1       1    male  40.0      0      0  31.0000        C  First
# 510         1       3    male  29.0      0      0   7.7500        Q  Third
# 294         0       3    male  24.0      0      0   7.8958        S  Third
# 138         0       3    male  16.0      0      0   9.2167        S  Third
# 628         0       3    male  26.0      0      0   7.8958        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 461         0       3    male  34.0      0      0   8.0500        S  Third
# 68          1       3  female  17.0      4      2   7.9250        S  Third
# 106         1       3  female  21.0      0      0   7.6500        S  Third
# 23          1       1    male  28.0      0      0  35.5000        S  First
# 611         0       3    male   NaN      0      0   7.0500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# boolian indexing
df[df["A"]> 0]
# Out:
#                    A         B         C         D
# 2023-11-26  1.294859 -1.208097  1.799979  1.594176

# %%
kashti[kashti["age"]< 5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
kashti[kashti["age"]< 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 305  child       False    C  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# ...

# %%
kashti[kashti["age"]> 60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
kashti[kashti["fare"]< 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# ...
