# %% [markdown]
# # Advance use of Pandas libraries
# Author: Taskeen Hussin\
# Date: 25-11-24\
# email: taskeenuaf@gmail.com

# %% [markdown]
#  # Advance use of Pandas libraries
# # 1. Data manipulation\
# import pandas as pd\
# import numpy as np\
# # Create a DataFrame\
# df = pd.DataFrame({\
#     'Name': ['Tom', 'Nick', 'John', 'Tom', 'John'],\
#     'Age': [20, 21, 19, 20, 19],\
#     'Score': [90, 85, 88, 92, 89],\
#     'Gender': ['Male', 'Male', 'Male', 'Male', 'Male']\
#     })\
#     # Print the DataFrame\
#     print(df)\
#     # 2. Data analysis\
#     # Calculate the mean of 'Score' column\
#     df['Mean_Score'] = df['Score'].mean()\
#     # Print the DataFrame\
#     print(df)\

# %%
import pandas as pd
import numpy as np

# %%
#load dataset for work
import seaborn as sns

# Load titanic datset
sns.load_dataset('Titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti = sns.load_dataset('Titanic')

# %%
kashti.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
# What every column means in kashti dataset?
# How many data sets are there in seaborn and how to fetch it?

# %%
# Download phool dataset
# search it what is iris and what is means and why it is used in machine learning and deep learning 
phool = sns.load_dataset('iris')
phool.sample(100)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 69            5.6          2.5           3.9          1.1  versicolor
# 133           6.3          2.8           5.1          1.5   virginica
# 76            6.8          2.8           4.8          1.4  versicolor
# 20            5.4          3.4           1.7          0.2      setosa
# 49            5.0          3.3           1.4          0.2      setosa
# ..            ...          ...           ...          ...         ...
# 99            5.7          2.8           4.1          1.3  versicolor
# 144           6.7          3.3           5.7          2.5   virginica
# 139           6.9          3.1           5.4          2.1   virginica
# 109           7.2          3.6           6.1          2.5   virginica
# 147           6.5          3.0           5.2          2.0   virginica
#
# [100 rows x 5 columns]

# %%
phool.to_excel('iris.xlsx')

# %%
kashti.to_excel('kashti.xlsx')

# %%
# To export a dataset If you have to send data to other day folder then give path of the folder and also mention the name in same string, then it will works
kashti.to_excel('../day_7/kashti.xlsx')

# %%
df = pd.read_excel('kashti.xlsx')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# you can search columns by entering name of the column in string
# Selecting one column is called 1 D array(dimensional) 1D means only columns
# Selecting more then 1 column is called 2D array (dimensional)
# 2D means  relationship of rows and columns
df[['embarked', 'embark_town', 'survived', 'who', 'sex', 'fare']]
# Out:
#     embarked  embark_town  survived    who     sex     fare
# 0          S  Southampton         0    man    male   7.2500
# 1          C    Cherbourg         1  woman  female  71.2833
# 2          S  Southampton         1  woman  female   7.9250
# 3          S  Southampton         1  woman  female  53.1000
# 4          S  Southampton         0    man    male   8.0500
# ..       ...          ...       ...    ...     ...      ...
# 886        S  Southampton         0    man    male  13.0000
# 887        S  Southampton         1  woman  female  30.0000
# 888        S  Southampton         0  woman  female  23.4500
# 889        C    Cherbourg         1    man    male  30.0000
# 890        Q   Queenstown         0    man    male   7.7500
#
# [891 rows x 6 columns]

# %%
# nan means (not a number), missing values, null values
df.embark_town.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.deck.unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df.drop(columns='Unnamed: 0') # how to drop a column its assignment

# %%
df.groupby(['sex']).describe().T
# Out:
# sex                 female        male
# survived count  314.000000  577.000000
#          mean     0.742038    0.188908
#          std      0.438211    0.391775
#          min      0.000000    0.000000
#          25%      0.000000    0.000000
#          50%      1.000000    0.000000
#          75%      1.000000    0.000000
#          max      1.000000    1.000000
# pclass   count  314.000000  577.000000
#          mean     2.159236    2.389948
#          std      0.857290    0.813580
#          min      1.000000    1.000000
#          25%      1.000000    2.000000
#          50%      2.000000    3.000000
#          75%      3.000000    3.000000
#          max      3.000000    3.000000
# age      count  261.000000  453.000000
#          mean    27.915709   30.726645
#          std     14.110146   14.678201
#          min      0.750000    0.420000
#          25%     18.000000   21.000000
#          50%     27.000000   29.000000
#          75%     37.000000   39.000000
# ...

# %%
# count the number of survived = 1 grouped by sex (male or female)
df.groupby(['survived', 'sex']).count()
# Out:
#                  pclass  age  sibsp  parch  fare  embarked  class  who  \
# survived sex
# 0        female      81   64     81     81    81        81     81   81
#          male       468  360    468    468   468       468    468  468
# 1        female     233  197    233    233   233       231    233  233
#          male       109   93    109    109   109       109    109  109
#
#                  adult_male  deck  embark_town  alive  alone
# survived sex
# 0        female          81     6           81     81     81
#          male           468    61          468    468    468
# 1        female         233    91          231    233    233
#          male           109    45          109    109    109

# %% [markdown]
# ## count the number of survived = 1 grouped by sex (male or female)
# ## Hyposthesis: Any uncertian situation when you have to save one of them is first save females and kids b/c family grows with women and kids(inheritance)

# %%
df.groupby(['survived', 'sex'])['survived'].count()
# Out:
# survived  sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: survived, dtype: int64

# %%
df.groupby(['survived', 'sex','who'])['who'].count()
# Out:
# survived  sex     who
# 0         female  child     15
#                   woman     66
#           male    child     19
#                   man      449
# 1         female  child     28
#                   woman    205
#           male    child     21
#                   man       88
# Name: who, dtype: int64

# %%
sns.countplot(x='survived', data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived', hue='sex', data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ### use of pandas website to know how it works
# ### use of numpy website
